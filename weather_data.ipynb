# %% [markdown]
# # **Weather Dataset**

# %% [markdown]
# # ***Columns***
#
# | **Column Name**    | **Description**                                                                                                       | **Meaning**                                                |
# | ------------------ | --------------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------- |
# | `Date/Time`        | The **timestamp** of the weather reading. Format: `MM/DD/YYYY HH:MM` (24-hour).                                       | The exact date and time when weather data was recorded.                    |
# | `Temp_C`           | **Air temperature** in degrees Celsius (`°C`).                                                                        | The hotness or coldness of air at that time.                               |
# | `Dew Point Temp_C` | **Dew point** temperature in °C. Indicates the temperature at which air is saturated with moisture.                   | The temperature at which water drops (dew) start to form in the air.       |
# | `Rel Hum_%`        | **Relative Humidity** in percentage (`%`). Shows how much moisture is in the air compared to the maximum it can hold. | How full the air is with water; 100% means it can't hold more.             |
# | `Wind Speed_km/h`  | **Wind speed** in kilometers per hour (`km/h`).                                                                       | How fast the air (wind) is moving.                                         |
# | `Visibility_km`    | **Visibility distance** in kilometers. Shows how far one can see clearly.                                             | How far a person can see things in front of them.                          |
# | `Press_kPa`        | **Atmospheric pressure** in kilopascals (`kPa`). Lower values can indicate storms or bad weather.                     | The weight of the air pressing down; low values often mean rain or storms. |
# | `Weather`          | **Weather condition** description, like *Fog*, *Freezing Drizzle*, *Mostly Cloudy*, etc.                              | Words that describe what's happening in the sky, like fog or rain.         |

# %% [markdown]
# # ***Exploratory Data Analysis(EDA).***

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('1. Weather_Data.csv')

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.nunique() # Works on both columns and rows
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.Weather.unique() # Works only for a single column.
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.count() #  tells you the number of non-null (non-missing) values in 
# each column of the DataFrame.
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df1 = df.copy()

# %%
df1.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df1['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
df1.dtypes
# Out:
# Date/Time           datetime64[ns]
# Temp_C                     float64
# Dew Point Temp_C           float64
# Rel Hum_%                    int64
# Wind Speed_km/h              int64
# Visibility_km              float64
# Press_kPa                  float64
# Weather                     object
# dtype: object

# %% [markdown]
# # ***Feature Engineering.***

# %%
df1.insert(0,'Date',df1['Date/Time'].dt.date)

df1.insert(0,'Time_H',df1['Date/Time'].dt.hour)

# %%
df1.head()
# Out:
#    Time_H        Date           Date/Time  Temp_C  Dew Point Temp_C  \
# 0       0  2012-01-01 2012-01-01 00:00:00    -1.8              -3.9
# 1       1  2012-01-01 2012-01-01 01:00:00    -1.8              -3.7
# 2       2  2012-01-01 2012-01-01 02:00:00    -1.8              -3.4
# 3       3  2012-01-01 2012-01-01 03:00:00    -1.5              -3.2
# 4       4  2012-01-01 2012-01-01 04:00:00    -1.5              -3.3
#
#    Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0         86                4            8.0     101.24                   Fog
# 1         87                4            8.0     101.24                   Fog
# 2         89                7            4.0     101.26  Freezing Drizzle,Fog
# 3         88                6            4.0     101.27  Freezing Drizzle,Fog
# 4         88                7            4.8     101.23                   Fog

# %%
df1.drop('Date/Time',axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Time_H        Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       0  2012-01-01    -1.8              -3.9         86                4
# 1       1  2012-01-01    -1.8              -3.7         87                4
# 2       2  2012-01-01    -1.8              -3.4         89                7
# 3       3  2012-01-01    -1.5              -3.2         88                6
# 4       4  2012-01-01    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
hourly_temp = df1.groupby('Time_H')['Temp_C'].mean()
hourly_temp
# Out:
# Time_H
# 0      7.568579
# 1      7.090437
# 2      6.656011
# 3      6.291803
# 4      5.969126
# 5      5.717760
# 6      6.033060
# 7      6.572951
# 8      7.378142
# 9      8.326230
# 10     9.277596
# 11    10.107650
# 12    10.856557
# 13    11.393716
# 14    11.775956
# 15    11.884153
# 16    11.765574
# 17    11.276503
# 18    10.656284
# 19    10.022951
# 20     9.360109
# 21     8.806557
# 22     8.369399
# 23     7.998361
# Name: Temp_C, dtype: float64

# %% [markdown]
# #  ***Visualize the Trends***
# - Plot temperature over time

# %%
plt.figure(figsize=(10,7))
plt.plot(hourly_temp.index,hourly_temp.values,marker='o')
plt.title('Average Temperature By Hours of Day.')
plt.xlabel('Hour of Day')
plt.ylabel('Average Temperature')
plt.grid()
plt.xticks(range(0,24))
plt.show()

# %% [markdown]
# - Show how humidity or wind speed changes in a day or month

# %%
df1.head(2)
# Out:
#    Time_H        Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       0  2012-01-01    -1.8              -3.9         86                4
# 1       1  2012-01-01    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
plt.figure(figsize=(10,7))
plt.plot(df1['Date'],df1['Rel Hum_%'])
plt.title('Speed of humidity changes With date')
plt.xlabel('Date')
plt.ylabel('Humidity')
plt.grid()

plt.show()

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df1['Day'] = df1['Date'].dt.day
df1['Month'] = df1['Date'].dt.month
df1['Year'] = df1['Date'].dt.year

df1.drop('Date',axis=1,inplace=True)

# %%
df1.head(2)
# Out:
#    Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       0    -1.8              -3.9         86                4
# 1       1    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather  Day  Month  Year
# 0            8.0     101.24     Fog    1      1  2012
# 1            8.0     101.24     Fog    1      1  2012

# %%
df1.dtypes
# Out:
# Time_H                int32
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# Day                   int32
# Month                 int32
# Year                  int32
# dtype: object

# %%
monthly_humidity = df1.groupby('Month')['Rel Hum_%'].mean()
monthly_humidity
# Out:
# Month
# 1     68.383065
# 2     68.956897
# 3     64.862903
# 4     56.150000
# 5     61.760753
# 6     60.643056
# 7     62.017473
# 8     67.943548
# 9     71.165278
# 10    75.731183
# 11    69.984722
# 12    81.299731
# Name: Rel Hum_%, dtype: float64

# %%
plt.figure(figsize=(10,7))
plt.plot(monthly_humidity.index,
         monthly_humidity.values,
         color='red',marker='o',
         linestyle='--',
         markerfacecolor='black')
plt.title('Speed of humidity changes over months')
plt.xlabel('Month')
plt.ylabel('Average Humidity')
plt.grid()

plt.show()

# %% [markdown]
# # ***Analyze Weather Patterns***
# - When was the fog most common?
# - What kind of weather is linked with low visibility or high humidity?

# %%
df1.head(2)
# Out:
#    Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       0    -1.8              -3.9         86                4
# 1       1    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather  Day  Month  Year
# 0            8.0     101.24     Fog    1      1  2012
# 1            8.0     101.24     Fog    1      1  2012

# %%
fog_df = df1[df1['Weather'].str.contains('Fog',na=False)]
fog_df
# Out:
#       Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0          0    -1.8              -3.9         86                4
# 1          1    -1.8              -3.7         87                4
# 2          2    -1.8              -3.4         89                7
# 3          3    -1.5              -3.2         88                6
# 4          4    -1.5              -3.3         88                7
# ...      ...     ...               ...        ...              ...
# 8739       3    -9.1             -10.4         90               11
# 8740       4    -9.3             -10.6         90               13
# 8741       5    -9.1             -10.4         90               11
# 8742       6    -9.3             -10.8         89               17
# 8770      10    -7.4              -8.9         89                4
#
#       Visibility_km  Press_kPa               Weather  Day  Month  Year
# 0               8.0     101.24                   Fog    1      1  2012
# ...

# %%
fog_df1 = df1[df1['Weather'] == 'Fog']
fog_df1
# Out:
#       Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0          0    -1.8              -3.9         86                4
# 1          1    -1.8              -3.7         87                4
# 4          4    -1.5              -3.3         88                7
# 5          5    -1.4              -3.3         87                9
# 6          6    -1.5              -3.1         89                7
# ...      ...     ...               ...        ...              ...
# 8716       4   -16.0             -17.2         90                6
# 8717       5   -14.8             -15.9         91                4
# 8718       6   -13.8             -15.3         88                4
# 8719       7   -14.8             -16.4         88                7
# 8722      10   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather  Day  Month  Year
# 0               8.0     101.24     Fog    1      1  2012
# ...

# %%
# .size() counts how many times fog happened on each day.
fog_counts = fog_df1.groupby(['Year','Month','Day']).size().reset_index(name='Time_H')
fog_counts
# Out:
#     Year  Month  Day  Time_H
# 0   2012      1    1      14
# 1   2012      1    7       1
# 2   2012      1   18       1
# 3   2012      1   22       2
# 4   2012      2    3       1
# 5   2012      2   15       2
# 6   2012      2   16       1
# 7   2012      2   23       4
# 8   2012      3    2       1
# 9   2012      3   13       4
# 10  2012      3   14       9
# 11  2012      3   16       6
# 12  2012      3   17      10
# 13  2012      3   21       2
# 14  2012      3   28       3
# 15  2012      4    2       3
# 16  2012      4   24       1
# 17  2012      5    1       1
# 18  2012      5    2       9
# 19  2012      5    4       1
# 20  2012      5    8       3
# 21  2012      5    9       2
# 22  2012      7   16       1
# 23  2012      8   10       2
# 24  2012      8   12       2
# 25  2012      9   21       1
# 26  2012      9   22       1
# 27  2012     10    3       6
# 28  2012     10    4      10
# 29  2012     10   14       5
# 30  2012     10   20       7
# ...

# %%
max_fog_day = fog_counts.sort_values(by='Time_H', ascending=False).iloc[0]
print(f'Fog Occurs The Most on {max_fog_day['Year']}-{max_fog_day['Month']}-{max_fog_day['Day']} with {max_fog_day['Time_H']} hours')
# Out:
# Fog Occurs The Most on 2012-1-1 with 14 hours

# %% [markdown]
# - What kind of weather is linked with low visibility or high humidity?

# %%
df1.head(2)
# Out:
#    Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       0    -1.8              -3.9         86                4
# 1       1    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather  Day  Month  Year
# 0            8.0     101.24     Fog    1      1  2012
# 1            8.0     101.24     Fog    1      1  2012

# %%
low_visibility_df1 = df1[df1['Visibility_km'] < 2.0]
low_visibility_df1
# Out:
#       Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 10        10    -1.0              -2.3         91                9
# 277       13    -5.8              -8.6         81               33
# 278       14    -5.7              -8.5         81               28
# 279       15    -5.2              -7.6         83               26
# 280       16    -4.9              -7.3         83               33
# ...      ...     ...               ...        ...              ...
# 8677      13    -5.4              -6.7         91               48
# 8678      14    -5.2              -6.7         89               46
# 8679      15    -5.0              -6.2         91               37
# 8727      15    -8.8             -10.0         91               20
# 8728      16    -8.5              -9.9         90               24
#
#       Visibility_km  Press_kPa            Weather  Day  Month  Year
# 10              1.2     101.15                Fog    1      1  2012
# ...

# %%
plt.figure(figsize=(10,8))
weather_low_visi=low_visibility_df1['Weather'].value_counts()
plt.pie(weather_low_visi,
        labels=weather_low_visi.index,
        autopct='%2.1f%%',
       
        shadow=True,
        colors = sns.color_palette('pastel')[0:4],
        textprops={'fontsize':12}
        )
plt.axis('equal')
plt.title('Weather Contains Lower Visibility.',fontsize=14)
plt.show()

# %% [markdown]
# # ***Group Data by Time***
# - Group by day/month to see average temperature, humidity, etc.

# %%
df1.head(2)
# Out:
#    Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       0    -1.8              -3.9         86                4
# 1       1    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather  Day  Month  Year
# 0            8.0     101.24     Fog    1      1  2012
# 1            8.0     101.24     Fog    1      1  2012

# %%
avg_temp_hum_df1 = df1.groupby(['Month','Day'])[['Temp_C','Rel Hum_%']].mean().reset_index()
avg_temp_df1
# Out:
#      Month  Day     Temp_C  Rel Hum_%
# 0        1    1   0.629167  86.125000
# 1        1    2   0.041667  63.083333
# 2        1    3 -14.416667  54.791667
# 3        1    4 -13.645833  62.875000
# 4        1    5  -6.750000  70.000000
# ..     ...  ...        ...        ...
# 361     12   27  -5.833333  88.833333
# 362     12   28  -6.775000  83.083333
# 363     12   29 -11.345833  88.666667
# 364     12   30 -11.370833  79.791667
# 365     12   31  -5.604167  84.750000
#
# [366 rows x 4 columns]

# %% [markdown]
# - Find out which month had most fog or rain

# %%
fog_df = df1[df1['Weather'].str.contains('Fog', case=False, na=False)]
most_foggy_month = fog_df.groupby('Month').size().idxmax()
print("Month with most fog:", most_foggy_month)
# Out:
# Month with most fog: 12

# %% [markdown]
#  # ***case= False***
#   This ignores case sensitivity.
#
#  So it matches "fog", "Fog", "FOG", etc.
#
# # ***na=False***
# This handles missing values (i.e., NaN in 'Weather' column).
#
# Without this, if any row has NaN, it would raise an error.
#
# na=False means: treat missing values as if they do not match (i.e., False).

# %%
fog_df = df1[df1['Weather'].str.contains('Rain', case=False, na=False)]
most_rainy_month = fog_df.groupby('Month').size().idxmax()
print("Month with most rain:", most_rainy_month)
# Out:
# Month with most rain: 4

# %% [markdown]
# # ***Detect Extremes & Alerts***
# - When was visibility below 1 km (dangerous)?

# %%
df1.head(2)
# Out:
#    Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       0    -1.8              -3.9         86                4
# 1       1    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather  Day  Month  Year
# 0            8.0     101.24     Fog    1      1  2012
# 1            8.0     101.24     Fog    1      1  2012

# %%
visibility = df1[df1['Visibility_km'] < 1]
visibility
# Out:
#       Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 279       15    -5.2              -7.6         83               26
# 280       16    -4.9              -7.3         83               33
# 510        6   -19.0             -22.9         71                6
# 850       10   -11.1             -13.4         83                9
# 1754       2     0.6              -1.0         89                7
# 1755       3     0.8              -0.3         92                6
# 1756       4     0.8              -0.6         90                4
# 1757       5     0.7              -0.9         89                6
# 1758       6     0.6              -0.9         90                7
# 1825       1     3.0               2.7         98                6
# 1826       2     2.7               2.5         99                4
# 1827       3     1.8               1.6         99                4
# 1828       4     0.3               0.1         99                0
# ...

# %%
visibility.shape
# Out:
# (34, 11)

# %%
df1.head(2)
# Out:
#    Time_H  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       0    -1.8              -3.9         86                4
# 1       1    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather  Day  Month  Year
# 0            8.0     101.24     Fog    1      1  2012
# 1            8.0     101.24     Fog    1      1  2012

# %%
num = df1.select_dtypes(include='number')
corr = num.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True,
            cmap='coolwarm',
             square=True,
            cbar_kws={"shrink": 0.8})
plt.title('Correlation Heatmap of Numeric Features',fontsize=14)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
